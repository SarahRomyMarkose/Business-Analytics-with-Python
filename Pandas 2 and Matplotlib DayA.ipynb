# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rc('font', size=15)          # controls default text sizes
plt.rc('axes', titlesize=15)     # fontsize of the axes title
plt.rc('axes', labelsize=25)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=15)    # legend fontsize
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# %%
df=pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#        InvoiceID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
df.loc[0, "City"] #Just like Vlookup, we locate the required data with such commands
# Out:
# 'Yangon'

# %%
df.loc[4,"Tax"]
# Out:
# 30.2085

# %%
new_data=[len(df)]
for x in df.index:
    new_data.append(df.loc[x, "City"])
new_data
# Out:
# [1000,
#  'Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Yangon',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Naypyitaw',
#  'Mandalay',
# ...

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x, "Branch"] == "A"):
        new_data.append(df.loc[x, "InvoiceID"])
new_data
# Out:
# [1000,
#  '750-67-8428',
#  '631-41-3108',
#  '123-19-1176',
#  '373-73-7910',
#  '355-53-5943',
#  '665-32-9167',
#  '365-64-0515',
#  '252-56-2699',
#  '829-34-3910',
#  '656-95-9349',
#  '765-26-6951',
#  '329-62-1586',
#  '636-48-8204',
#  '549-59-1358',
#  '227-03-5010',
#  '189-17-4241',
#  '848-62-7243',
#  '595-11-5460',
#  '129-29-8530',
#  '272-65-1806',
#  '162-48-8011',
#  '106-35-6779',
#  '635-40-6220',
#  '817-48-8732',
#  '199-75-8169',
#  '877-22-3308',
#  '232-11-3025',
#  '382-03-4532',
#  '287-21-9091',
#  '381-20-0914',
#  '633-44-8566',
#  '504-35-8843',
#  '873-51-0671',
#  '594-34-4444',
#  '865-92-6136',
#  '212-62-1842',
#  '704-48-3927',
#  '630-74-5166',
#  '645-44-1170',
#  '642-32-2990',
#  '638-60-7125',
#  '668-90-8900',
#  '870-54-3162',
#  '802-70-5316',
#  '700-81-1757',
#  '354-39-5160',
#  '575-30-8091',
#  '239-10-7476',
#  '685-64-1609',
#  '238-49-0436',
#  '746-94-0204',
#  '782-95-9291',
#  '275-28-0149',
#  '101-17-6199',
#  '687-47-8271',
# ...

# %%
new_data=[len(df)] #Q1(a)
for x in df.index:
    new_data.append(df.loc[x, "Unitprice"])
max(new_data)
# Out:
# 1000

# %%
new_data=[len(df)] #Q1(b)
for x in df.index:
    new_data.append(df.loc[x, "Unitprice"])
min(new_data)
# Out:
# 10.08

# %%
new_data=[len(df)] #Q1(c)
for x in df.index:
    new_data.append(df.loc[x, "Unitprice"])
sum(new_data)/1000
# Out:
# 56.672129999999974

# %%
new_data=[len(df)] #Q2(a)
for x in df.index:
    new_data.append(df.loc[x, "Quantity"])
max(new_data)
# Out:
# 1000

# %%
new_data=[len(df)] #Q2(b)
for x in df.index:
    new_data.append(df.loc[x, "Quantity"])
min(new_data)
# Out:
# 1

# %%
new_data=[len(df)] #Q2(c)
for x in df.index:
    new_data.append(df.loc[x, "Quantity"])
sum(new_data)/1000
# Out:
# 6.51

# %%
new_data=[len(df)] #Q4(a)
for x in df.index:
    if (df.loc[x, "Productline"] == "Health and beauty"):
        new_data.append(df.loc[x, "Unitprice"])
max(new_data)
# Out:
# 1000

# %%
new_data=[len(df)] #Q4(b)
for x in df.index:
    if (df.loc[x, "Productline"] == "Health and beauty"):
        new_data.append(df.loc[x, "Unitprice"])
min(new_data)
# Out:
# 10.08

# %%
new_data=[len(df)] #Q4(c)
for x in df.index:
    if (df.loc[x, "Productline"] == "Health and beauty"):
        new_data.append(df.loc[x, "Unitprice"])
sum(new_data)/1000
# Out:
# 9.33788

# %%
new_data=[len(df)] #Q3(a)
for x in df.index:
    if (df.loc[x, "Productline"] == "Health and beauty"):
        new_data.append(df.loc[x, "Quantity"])
max(new_data)
# Out:
# 1000

# %%
new_data=[len(df)] #Q3(b)
for x in df.index:
    if (df.loc[x, "Productline"] == "Health and beauty"):
        new_data.append(df.loc[x, "Quantity"])
min(new_data)
# Out:
# 1

# %%
new_data=[len(df)] #Q3(c)
for x in df.index:
    if (df.loc[x, "Productline"] == "Health and beauty"):
        new_data.append(df.loc[x, "Quantity"])
sum(new_data)/1000
# Out:
# 1.854
