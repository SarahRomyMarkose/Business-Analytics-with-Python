# %%
import pandas as pd

# %%
df=pd.read_csv("marketing_data .csv")
df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00        0
# 1         1        1961  Graduation         Single  $57,091.00        0
# 2     10476        1958  Graduation        Married  $67,267.00        0
# 3      1386        1967  Graduation       Together  $32,474.00        1
# 4      5371        1989  Graduation         Single  $21,474.00        1
# ...     ...         ...         ...            ...         ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00        0
# 2236   5263        1977    2n Cycle        Married  $31,056.00        1
# 2237     22        1976  Graduation       Divorced  $46,310.00        1
# 2238    528        1978  Graduation        Married  $65,819.00        0
# 2239   4070        1969         PhD        Married  $94,871.00        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
#SET RS

# %%
newdata=[] #Q1

for x in df.index:
    if(df.loc[x,"Year_Birth"]<1985):
        print(df.loc[x,"ID"])
# Out:
# 1826
# 1
# 10476
# 1386
# 7348
# 4073
# 1991
# 4047
# 9477
# 2079
# 5642
# 10530
# 2964
# 10311
# 837
# 10521
# 10175
# 1473
# 2795
# 2285
# 115
# 10470
# 4065
# 10968
# 5985
# 5430
# 8432
# 453
# 9687
# 8890
# 5824
# 5794
# 2681
# 10141
# 3725
# 3767
# 5585
# 7030
# 1524
# 5740
# 9595
# 3158
# 5114
# 340
# 8805
# 1241
# 1402
# 7264
# 1619
# 6398
# 1857
# 4877
# 3066
# 10286
# 1992
# 4246
# 10623
# 4867
# 3112
# 4865
# 4405
# 5332
# 1519
# 9080
# 1772
# 5341
# 5510
# 3887
# 7022
# 9999
# 10352
# 7919
# 4114
# 7990
# 9888
# 4399
# 4452
# 4785
# 8461
# 3878
# 4098
# 158
# 3896
# 9970
# 4002
# 10914
# 7279
# 10582
# 4470
# 6183
# 6379
# 8601
# 4827
# 6715
# 10676
# 1041
# 492
# 11133
# 4491
# 873
# 1631
# 6815
# 254
# 1349
# 2534
# 2130
# 2296
# 3799
# 11084
# 5172
# 9504
# 850
# 4477
# 1945
# 7685
# 6310
# 10832
# 3025
# 2404
# 8581
# 8755
# 10177
# 2429
# 8920
# 8430
# 8619
# 8996
# 7233
# 2261
# 10089
# 9256
# 10641
# 624
# 10356
# 9323
# 1146
# 6343
# 8545
# 8275
# 10673
# 8799
# ...

# %%
for x in df.index: #Q2
    if(df.loc[x,"Marital_Status"]=="Single"):
        print(df.loc[x,"ID"])
# Out:
# 1
# 5371
# 7348
# 1473
# 2795
# 115
# 10968
# 5985
# 9687
# 7962
# 3725
# 5585
# 1524
# 3657
# 8805
# 7264
# 1857
# 4246
# 4867
# 1519
# 9080
# 3887
# 4452
# 3878
# 9612
# 10914
# 4827
# 6715
# 1041
# 850
# 3025
# 8920
# 830
# 9256
# 10641
# 624
# 67
# 9923
# 4320
# 2546
# 3005
# 2930
# 9930
# 232
# 5682
# 1497
# 263
# 4619
# 940
# 1463
# 10855
# 3524
# 8897
# 2634
# 10150
# 2552
# 1388
# 979
# 3312
# 1446
# 9790
# 5080
# 6853
# 7366
# 7573
# 8923
# 6205
# 5626
# 7600
# 7002
# 4459
# 10642
# 9362
# 5726
# 9493
# 7141
# 10779
# 10133
# 8443
# 6507
# 6072
# 9392
# 6471
# 7848
# 3629
# 11086
# 7000
# 9369
# 9596
# 9242
# 5255
# 3645
# 1381
# 2942
# 9648
# 4702
# 2811
# 9150
# 195
# 7786
# 10560
# 11004
# 4248
# 7451
# 5872
# 11187
# 1726
# 1162
# 10643
# 2114
# 4261
# 4286
# 3153
# 1839
# 9855
# 975
# 1456
# 2849
# 10395
# 1542
# 1506
# 6347
# 1012
# 8346
# 8029
# 4376
# 2286
# 10277
# 4436
# 2929
# 10343
# 4338
# 498
# 10736
# 10163
# 4656
# 10971
# 6679
# 5735
# 5350
# 10619
# 7922
# ...

# %%
for k in df.index: #Q3
    if (df.loc[k,"Education"]=="2n Cycle"):
        if ((df.loc[k,"Income"]>"$40000.00") & (df.loc[k,"Income"]<"$49000.00")):
            print(df.loc[k,'ID'])
# Out:
# 1473
# 7628
# 6116
# 5231
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-091d27f6fd48> in <module>
#       1 for k in df.index: #Q3
#       2     if (df.loc[k,"Education"]=="2n Cycle"):
# ----> 3         if ((df.loc[k,"Income"]>"$40000.00") & (df.loc[k,"Income"]<"$49000.00")):
#       4             print(df.loc[k,'ID'])
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
for k in df.index: #Q4
    if ((df.loc[k,"MntWines"]) & (df.loc[k,"MntFruits"])):
        print(df.loc[k,"ID"])
# Out:
# 1826
# 10476
# 2079
# 5642
# 10530
# 2964
# 837
# 10521
# 1473
# 2285
# 115
# 9687
# 8890
# 9264
# 7962
# 2681
# 10141
# 1524
# 9595
# 3158
# 5114
# 340
# 8805
# 1241
# 1402
# 1619
# 6398
# 10286
# 4246
# 4865
# 4405
# 5332
# 1519
# 9080
# 1772
# 5341
# 5510
# 3887
# 7022
# 9999
# 7919
# 7990
# 9888
# 4399
# 4452
# 158
# 9970
# 4002
# 7279
# 10582
# 6379
# 8601
# 4827
# 6715
# 10676
# 1041
# 492
# 11133
# 1631
# 8278
# 254
# 1349
# 2534
# 2130
# 2296
# 3799
# 9504
# 850
# 4477
# 1945
# 7685
# 6310
# 3025
# 2404
# 8755
# 10177
# 2429
# 8996
# 7233
# 830
# 6365
# 6770
# 1031
# 10089
# 9256
# 10641
# 624
# 4211
# 1407
# 9323
# 1146
# 6343
# 8545
# 10673
# 8799
# 2814
# 2711
# 4320
# 10451
# 4198
# 10814
# 944
# 3498
# 7342
# 1911
# 2546
# 3005
# 8318
# 2930
# 2541
# 10905
# 8910
# 7872
# 4290
# 8235
# 10949
# 9529
# 9930
# 10270
# 760
# 5519
# 232
# 3009
# 10669
# 1570
# 1497
# 9723
# 7261
# 2452
# 5621
# 5331
# 263
# 4619
# 940
# 10084
# 6019
# 6424
# 8233
# 1515
# 10855
# 3376
# ...

# %%
df.loc[df["MntFruits"]].mean() #Q5
# Out:
# ID                     4514.161607
# Year_Birth             1966.870089
# Kidhome                   0.307143
# Teenhome                  0.433482
# Recency                   0.705804
# MntWines                255.770536
# MntFruits                36.586607
# MntMeatProducts         179.872321
# MntFishProducts          45.937946
# MntSweetProducts         48.710268
# MntGoldProds             66.941964
# NumDealsPurchases         1.756696
# NumWebPurchases           4.202232
# NumCatalogPurchases       2.758929
# NumStorePurchases         5.374107
# NumWebVisitsMonth         4.161607
# AcceptedCmp3              0.084821
# AcceptedCmp4              0.019643
# AcceptedCmp5              0.027679
# AcceptedCmp1              0.041964
# AcceptedCmp2              0.079911
# Response                  0.487500
# Complain                  0.000000
# dtype: float64

# %%
df.loc[df["MntFruits"]].mean() #Q6
# Out:
# ID                     4514.161607
# Year_Birth             1966.870089
# Kidhome                   0.307143
# Teenhome                  0.433482
# Recency                   0.705804
# MntWines                255.770536
# MntFruits                36.586607
# MntMeatProducts         179.872321
# MntFishProducts          45.937946
# MntSweetProducts         48.710268
# MntGoldProds             66.941964
# NumDealsPurchases         1.756696
# NumWebPurchases           4.202232
# NumCatalogPurchases       2.758929
# NumStorePurchases         5.374107
# NumWebVisitsMonth         4.161607
# AcceptedCmp3              0.084821
# AcceptedCmp4              0.019643
# AcceptedCmp5              0.027679
# AcceptedCmp1              0.041964
# AcceptedCmp2              0.079911
# Response                  0.487500
# Complain                  0.000000
# dtype: float64

# %%
df.loc[df["MntFruits"]].max() #Q6
# Out:
# ID                      11133
# Year_Birth               1990
# Education                 PhD
# Marital_Status           YOLO
# Kidhome                     2
# Teenhome                    2
# Dt_Customer            9/9/13
# Recency                     8
# MntWines                 1296
# MntFruits                 193
# MntMeatProducts           981
# MntFishProducts           259
# MntSweetProducts          197
# MntGoldProds              321
# NumDealsPurchases          12
# NumWebPurchases            25
# NumCatalogPurchases        10
# NumStorePurchases          13
# NumWebVisitsMonth          17
# AcceptedCmp3                1
# AcceptedCmp4                1
# AcceptedCmp5                1
# AcceptedCmp1                1
# AcceptedCmp2                1
# Response                    1
# Complain                    0
# Country                    US
# dtype: object

# %%
df.loc[df["MntFruits"]].min() #Q6
# Out:
# ID                            1
# Year_Birth                 1945
# Education              2n Cycle
# Marital_Status         Divorced
# Kidhome                       0
# Teenhome                      0
# Dt_Customer              1/1/14
# Recency                       0
# MntWines                      1
# MntFruits                     0
# MntMeatProducts               1
# MntFishProducts               0
# MntSweetProducts              0
# MntGoldProds                  0
# NumDealsPurchases             0
# NumWebPurchases               0
# NumCatalogPurchases           0
# NumStorePurchases             0
# NumWebVisitsMonth             0
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Response                      0
# Complain                      0
# Country                     AUS
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["MntFishProducts"],df["NumCatalogPurchases"]) #Q7

# %%
plt.scatter(df["MntFishProducts"],df["NumCatalogPurchases"]) #Q7

# %%
value = [522690,94171,79684,17011]
value
# Out:
# [522690, 94171, 79684, 17011]

# %%
print("Income: ", value[0])
print("HRA: ", value[1])
print("Insurance: ", value[2])
print("DA: ", value[3])
# Out:
# Income:  522690
# HRA:  94171
# Insurance:  79684
# DA:  17011

# %%
x=int(input("Insurance:")) #Case1
if x<150000:
    print("No Tax")
elif x>150000:
    T=(x-150000)*0.1
    print(T)
# Out:
# Insurance: 22000000
# 2185000.0

# %%
x=int(input("Income:")) #Case2
if x<=250000:
    print("No Tax")
elif x<=500000:
    T=(x-250000)*0.05
    print(T)
elif x<=750000:
    T=((x-500000)*0.1)+12500
    print(T)
elif x<=1000000:
    T=((x-750000)*0.15)+37500
    print(T)
elif x<=1250000:
    T=((x-1000000)*0.20)+75000
    print(T)
elif x<=1500000:
    T=((x-1250000)*0.25)+125000
    print(T)
elif x>1500000:
    T=((x-1500000)*0.30)+187500
    print(T)
# Out:
# Income: 30003938
# 8738681.4

# %%
x=int(input("HRA:")) #Case3
if x<52269:
    print("No Tax")
elif x>52269:
    T=52269+((x-52269)*0.50)
    print(T)
    
#Note: Here, Basic Pay= 522690
# 10% of Basic pay= 52269
# Out:
# HRA: 1000
# No Tax

# %%
x=int(input("DA:")) #Case4
if x<10000:
    print("No Tax")
elif x>10000:
    T=(x-10000)*0.1
    print(T)
# Out:
# DA: 100000
# 9000.0
