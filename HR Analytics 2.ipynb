# %%
#QUESTIONS : https://github.com/sarincr/Business-analytics-Course-with-Python/blob/main/Data%20Analytics/HR%20Analytics.pdf

# %%
import pandas as pd

# %%
df=pd.read_csv("HRDataset.csv")
df
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0         Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3                Alagbe,Trina  10088.0        1.0              1.0  Female
# 4            Anderson, Carol   10069.0        0.0              2.0    Male
# ..                        ...      ...        ...              ...     ...
# 307        Ybarra, Catherine   10301.0        0.0              0.0  Female
# 308          Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309               Zhou, Julia  10043.0        0.0              0.0    Male
# 310             Zima, Colleen  10271.0        0.0              4.0    Male
# 311                       NaN      NaN        NaN              NaN    Male
#
# ...

# %%
df.loc[df["StockOptionLevel"]==1].count() #Q12
# Out:
# Employee_Name                 126
# EmpID                         126
# MarriedID                     126
# MaritalStatusID               126
# Gender                        127
# EmpStatusID                   126
# DeptID                        126
# PerfScoreID                   126
# FromDiversityJobFairID        126
# Salary                        126
# Termd                         126
# PositionID                    126
# Position                      126
# State                         126
# Zip                           126
# DOB                           126
# Sex                           126
# MaritalDesc                   126
# CitizenDesc                   126
# DateofHire                    126
# DateofTermination              45
# TermReason                    126
# EmploymentStatus              126
# Department                    126
# ManagerName                   126
# ManagerID                     126
# RecruitmentSource             126
# ...

# %%
df.loc[df["PerformanceRating"]>3].count() #Q13
# Out:
# Employee_Name                 57
# EmpID                         57
# MarriedID                     57
# MaritalStatusID               57
# Gender                        57
# EmpStatusID                   57
# DeptID                        57
# PerfScoreID                   57
# FromDiversityJobFairID        57
# Salary                        57
# Termd                         57
# PositionID                    57
# Position                      57
# State                         57
# Zip                           57
# DOB                           57
# Sex                           57
# MaritalDesc                   57
# CitizenDesc                   57
# DateofHire                    57
# DateofTermination             16
# TermReason                    57
# EmploymentStatus              57
# Department                    57
# ManagerName                   57
# ManagerID                     53
# RecruitmentSource             57
# PerformanceScore              57
# ...

# %%
df.loc[df["EmpStatusID"]==5].count() #Q14
# Out:
# Employee_Name                 88
# EmpID                         88
# MarriedID                     88
# MaritalStatusID               88
# Gender                        88
# EmpStatusID                   88
# DeptID                        88
# PerfScoreID                   88
# FromDiversityJobFairID        88
# Salary                        88
# Termd                         88
# PositionID                    88
# Position                      88
# State                         88
# Zip                           88
# DOB                           88
# Sex                           88
# MaritalDesc                   88
# CitizenDesc                   88
# DateofHire                    88
# DateofTermination             88
# TermReason                    88
# EmploymentStatus              88
# Department                    88
# ManagerName                   88
# ManagerID                     88
# RecruitmentSource             88
# PerformanceScore              88
# ...

# %%
df.loc[df["Department"]=="IT/IS"].count() #Q15,Q16 and Q17
# Out:
# Employee_Name                 50
# EmpID                         50
# MarriedID                     50
# MaritalStatusID               50
# Gender                        50
# EmpStatusID                   50
# DeptID                        50
# PerfScoreID                   50
# FromDiversityJobFairID        50
# Salary                        50
# Termd                         50
# PositionID                    50
# Position                      50
# State                         50
# Zip                           50
# DOB                           50
# Sex                           50
# MaritalDesc                   50
# CitizenDesc                   50
# DateofHire                    50
# DateofTermination             10
# TermReason                    50
# EmploymentStatus              50
# Department                    50
# ManagerName                   50
# ManagerID                     50
# RecruitmentSource             50
# PerformanceScore              50
# ...

# %%
df.loc[df["Department"]=="Admin Offices"].count() #Q16 and Q17
# Out:
# Employee_Name                 9
# EmpID                         9
# MarriedID                     9
# MaritalStatusID               9
# Gender                        9
# EmpStatusID                   9
# DeptID                        9
# PerfScoreID                   9
# FromDiversityJobFairID        9
# Salary                        9
# Termd                         9
# PositionID                    9
# Position                      9
# State                         9
# Zip                           9
# DOB                           9
# Sex                           9
# MaritalDesc                   9
# CitizenDesc                   9
# DateofHire                    9
# DateofTermination             2
# TermReason                    9
# EmploymentStatus              9
# Department                    9
# ManagerName                   9
# ManagerID                     9
# RecruitmentSource             9
# PerformanceScore              9
# EngagementSurvey              9
# ...

# %%
df.loc[df["Department"]=="Production"].count() #Q16 and Q17
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# Gender                        0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# PerformanceScore              0
# EngagementSurvey              0
# ...

# %%
df.loc[df["Department"]=="Sales"].count() #Q16 and Q17
# Out:
# Employee_Name                 31
# EmpID                         31
# MarriedID                     31
# MaritalStatusID               31
# Gender                        31
# EmpStatusID                   31
# DeptID                        31
# PerfScoreID                   31
# FromDiversityJobFairID        31
# Salary                        31
# Termd                         31
# PositionID                    31
# Position                      31
# State                         31
# Zip                           31
# DOB                           31
# Sex                           31
# MaritalDesc                   31
# CitizenDesc                   31
# DateofHire                    31
# DateofTermination              5
# TermReason                    31
# EmploymentStatus              31
# Department                    31
# ManagerName                   31
# ManagerID                     31
# RecruitmentSource             31
# PerformanceScore              31
# ...

# %%
df.loc[df["Department"]=="Software Engineering"].count() #Q16 and Q17
# Out:
# Employee_Name                 11
# EmpID                         11
# MarriedID                     11
# MaritalStatusID               11
# Gender                        11
# EmpStatusID                   11
# DeptID                        11
# PerfScoreID                   11
# FromDiversityJobFairID        11
# Salary                        11
# Termd                         11
# PositionID                    11
# Position                      11
# State                         11
# Zip                           11
# DOB                           11
# Sex                           11
# MaritalDesc                   11
# CitizenDesc                   11
# DateofHire                    11
# DateofTermination              4
# TermReason                    11
# EmploymentStatus              11
# Department                    11
# ManagerName                   11
# ManagerID                     11
# RecruitmentSource             11
# PerformanceScore              11
# ...

# %%
df.loc[df["Department"]=="Executive Office"].count() #Q16 and Q17
# Out:
# Employee_Name                 1
# EmpID                         1
# MarriedID                     1
# MaritalStatusID               1
# Gender                        1
# EmpStatusID                   1
# DeptID                        1
# PerfScoreID                   1
# FromDiversityJobFairID        1
# Salary                        1
# Termd                         1
# PositionID                    1
# Position                      1
# State                         1
# Zip                           1
# DOB                           1
# Sex                           1
# MaritalDesc                   1
# CitizenDesc                   1
# DateofHire                    1
# DateofTermination             0
# TermReason                    1
# EmploymentStatus              1
# Department                    1
# ManagerName                   1
# ManagerID                     1
# RecruitmentSource             1
# PerformanceScore              1
# EngagementSurvey              1
# ...

# %%
#16 = IT/IS
#Q17 = Executive Office
#Some error occured in "Production"

# %%
#Q18 Not done

# %%
df.loc[df["FromDiversityJobFairID"]==1] #Q19
# Out:
#              Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 8         Bachiochi, Linda  10114.0        0.0              0.0    Male
# 10    Baczenski, Rachael    10252.0        1.0              1.0    Male
# 11         Barbara, Thomas  10242.0        1.0              1.0  Female
# 12        Barbossa, Hector  10012.0        0.0              2.0    Male
# 26       Boutwell, Bonalyn  10081.0        1.0              1.0  Female
# 29              Brown, Mia  10238.0        1.0              1.0  Female
# 31      Bugali, Josephine   10203.0        0.0              3.0    Male
# 103          Gerke, Melisa  10122.0        0.0              2.0  Female
# 105           Gilles, Alex  10283.0        1.0              1.0  Female
# 111         Gonzalez, Cayo  10031.0        0.0              2.0    Male
# 112         Gonzalez, Juan  10300.0        1.0              1.0  Female
# 155        Kreuger, Freddy  10165.0        0.0              0.0    Male
# ...

# %%
for k in df.index: #Q19
    if (df.loc[k,"Salary"]==df["Salary"].max()):
        print(df.loc[k,"Employee_Name"])
# Out:
# King, Janet

# %%
#Q19 => Highest paid employee was not chose for the Job fair
#Q20 Not done

# %%
df.loc[df["Position"]=="Executive Office"].count() #Q21 WRONG

# %%
df["Position"].unique() #Q21
# Out:
# array(['Production Technician I', 'Sr. DBA', 'Production Technician II',
#        'Software Engineer', 'IT Support', 'Data Analyst',
#        'Database Administrator', 'Enterprise Architect', 'Sr. Accountant',
#        'Production Manager', 'Accountant I', 'Area Sales Manager',
#        'Software Engineering Manager', 'BI Director',
#        'Director of Operations', 'Sr. Network Engineer', 'Sales Manager',
#        'BI Developer', 'IT Manager - Support', 'Network Engineer',
#        'IT Director', 'Director of Sales', 'Administrative Assistant',
#        'President & CEO', 'Senior BI Developer',
#        'Shared Services Manager', 'IT Manager - Infra',
#        'Principal Data Architect', 'Data Architect', 'IT Manager - DB',
#        'Data Analyst ', 'CIO', nan], dtype=object)

# %%
prodtech=0
for x in df["Position"].unique():
    if (df["Position"]=x):
        
        
#To be completed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-1a6729555166> in <module>
#       1 for x in df["Position"].unique():
# ----> 2     if (df.loc[x,"Position"]==df["Position"].count()):
#       3         print(df.loc[x,"Employee_Name"])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
# ...
