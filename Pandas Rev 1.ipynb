# %%
import pandas as pd

# %%
x=pd.read_excel("Sample superstore Copied.xlsx")
x
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
x.head() # This command will print only the first five rows.
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
x.tail() # This command will print only the last five rows.
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
x.index  # On importing an excel file, the           will automatically assign the index no. to the rows. These numberings are called 'Index'.
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
for k in x.index:
    print(x.City[k])
# Out:
# Henderson
# Henderson
# Los Angeles
# Fort Lauderdale
# Fort Lauderdale
# Los Angeles
# Los Angeles
# Los Angeles
# Los Angeles
# Los Angeles
# Los Angeles
# Los Angeles
# Concord
# Seattle
# Fort Worth
# Fort Worth
# Madison
# West Jordan
# San Francisco
# San Francisco
# San Francisco
# Fremont
# Fremont
# Philadelphia
# Orem
# Los Angeles
# Los Angeles
# Philadelphia
# Philadelphia
# Philadelphia
# Philadelphia
# Philadelphia
# Philadelphia
# Philadelphia
# Houston
# Richardson
# Richardson
# Houston
# Houston
# Houston
# Houston
# Naperville
# Los Angeles
# Melbourne
# Eagan
# Eagan
# Westland
# Dover
# Dover
# New Albany
# New Albany
# New Albany
# New Albany
# New York City
# New York City
# Troy
# Troy
# Troy
# Troy
# Troy
# Troy
# Troy
# Los Angeles
# Los Angeles
# Los Angeles
# Los Angeles
# Chicago
# Gilbert
# Gilbert
# Springfield
# New York City
# Jackson
# Memphis
# Memphis
# Memphis
# Houston
# Houston
# Houston
# Houston
# Decatur
# Decatur
# San Francisco
# ...

# %%
x.City
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
x.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
x.Sales.max()
# Out:
# 22638.48

# %%
x.Sales.min()
# Out:
# 0.44399999999999995

# %%
x.Sales.mean()
# Out:
# 229.8580008304938

# %%
x.Sales.count()
# Out:
# 9994

# %%
x.Sales.sum()
# Out:
# 2297200.8603000003

# %%
x.describe()  # This command shows the essential statistics of all the column.
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
x.groupby("City").count()
# Out:
#              Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# City
# Aberdeen          1         1           1          1          1            1
# Abilene           1         1           1          1          1            1
# Akron            21        21          21         21         21           21
# Albuquerque      14        14          14         14         14           14
# Alexandria       16        16          16         16         16           16
# ...             ...       ...         ...        ...        ...          ...
# Woonsocket        4         4           4          4          4            4
# Yonkers          15        15          15         15         15           15
# York              5         5           5          5          5            5
# Yucaipa           1         1           1          1          1            1
# Yuma              4         4           4          4          4            4
#
# ...

# %%
x.groupby("Customer Name").count()
# Out:
#                     Row ID  Order ID  Order Date  Ship Date  Ship Mode  \
# Customer Name
# Aaron Bergman            6         6           6          6          6
# Aaron Hawkins           11        11          11         11         11
# Aaron Smayling          10        10          10         10         10
# Adam Bellavance         18        18          18         18         18
# Adam Hart               20        20          20         20         20
# ...                    ...       ...         ...        ...        ...
# Xylona Preis            28        28          28         28         28
# Yana Sorensen           12        12          12         12         12
# Yoseph Carroll           8         8           8          8          8
# Zuschuss Carroll        31        31          31         31         31
# Zuschuss Donatelli       9         9           9          9          9
#
#                     Customer ID  Segment  Country  City  State  Postal Code  \
# Customer Name
# ...

# %%
x.loc[x["City"]=="Henderson"]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 538      539  CA-2015-134894 2015-12-07 2015-12-11  Standard Class
# 539      540  CA-2015-134894 2015-12-07 2015-12-11  Standard Class
# 996      997  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 997      998  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 998      999  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 999     1000  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 1866    1867  CA-2017-118857 2017-04-15 2017-04-18     First Class
# 2321    2322  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# 2322    2323  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# 2323    2324  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# 2324    2325  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# ...

# %%
x["City"]=="Henderson"
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: City, Length: 9994, dtype: bool

# %%
x.City
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
x["City"]   # The above and present command means the same.
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
x.loc[x["Segment"]=="Consumer"]  # This command will filter out City
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# 0       CG-12520       Claire Gute  Consumer  United States        Henderson
# ...

# %%
x["Sales"].loc[x["City"]=="Henderson"]  ####
# Out:
# 0        261.960
# 1        731.940
# 538      152.940
# 539      283.920
# 996       10.670
# 997       36.630
# 998       24.100
# 999       33.110
# 1866     196.450
# 2321      94.740
# 2322      60.640
# 2323      76.300
# 2324     364.800
# 2551     821.880
# 2552      21.960
# 3088      61.000
# 3089     671.930
# 3537      83.250
# 3538       9.450
# 3539      20.650
# 3540      45.360
# 4378      17.480
# 4379      71.880
# 4430      20.000
# 4431       7.980
# 4432      24.100
# 4433       8.750
# 4434     842.940
# 4840      27.580
# 4879       5.320
# 4880     975.920
# 4881    2249.910
# 4882      59.920
# 7090     106.320
# 7091     163.440
# 7092      42.760
# 7093      51.550
# 7114    1685.880
# 7115       5.728
# 7474    2573.820
# 7475     609.980
# 7476       5.480
# 7477     391.980
# 7478     755.960
# 7479      31.120
# 7480       6.540
# 8639      12.390
# 9074     828.840
# 9078     318.080
# 9079       5.800
# 9273    1577.940
# Name: Sales, dtype: float64

# %%
x["Sales"].loc[x["City"]=="Henderson"].max()  ####
# Out:
# 2573.82

# %%
x["Discount"].loc[x["Segment"]=="Consumer"].mean()  ####
# Out:
# 0.15814101329224042

# %%
x.loc[(x["Segment"]=="Consumer") & (x["Ship Mode"]=="Second Class")]  #####
# Out:
#       Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1          2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 17        18  CA-2014-167164 2014-05-13 2014-05-15  Second Class    AG-10270
# 18        19  CA-2014-143336 2014-08-27 2014-09-01  Second Class    ZD-21925
# 19        20  CA-2014-143336 2014-08-27 2014-09-01  Second Class    ZD-21925
# ...      ...             ...        ...        ...           ...         ...
# 9916    9917  CA-2017-160927 2017-01-29 2017-01-31  Second Class    TM-21010
# 9917    9918  CA-2017-160927 2017-01-29 2017-01-31  Second Class    TM-21010
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09  Second Class    SW-20455
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23  Second Class    TB-21400
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
# ...

# %%
x.loc[(x["Segment"]=="Consumer") & (x["Ship Mode"]=="Second Class")].count()
# Out:
# Row ID           1020
# Order ID         1020
# Order Date       1020
# Ship Date        1020
# Ship Mode        1020
# Customer ID      1020
# Customer Name    1020
# Segment          1020
# Country          1020
# City             1020
# State            1020
# Postal Code      1020
# Region           1020
# Product ID       1020
# Category         1020
# Sub-Category     1020
# Product Name     1020
# Sales            1020
# Quantity         1020
# Discount         1020
# Profit           1020
# dtype: int64

# %%
x.loc[(x["Segment"]=="Consumer") & (x["Ship Mode"]=="Second Class")].max()
# Out:
# Row ID                                                        9994
# Order ID                                            US-2017-169320
# Order Date                                     2017-12-29 00:00:00
# Ship Date                                      2018-01-01 00:00:00
# Ship Mode                                             Second Class
# Customer ID                                               ZD-21925
# Customer Name                                   Zuschuss Donatelli
# Segment                                                   Consumer
# Country                                              United States
# City                                                       Yonkers
# State                                                    Wisconsin
# Postal Code                                                  98632
# Region                                                        West
# Product ID                                         TEC-PH-10004908
# ...

# %%
x.loc[(x["Segment"]=="Consumer") & (x["Ship Mode"]=="Second Class")].min()
# Out:
# Row ID                                                           1
# Order ID                                            CA-2014-100706
# Order Date                                     2014-01-06 00:00:00
# Ship Date                                      2014-01-08 00:00:00
# Ship Mode                                             Second Class
# Customer ID                                               AA-10375
# Customer Name                                   Adam Shillingsburg
# Segment                                                   Consumer
# Country                                              United States
# City                                                      Aberdeen
# State                                                      Alabama
# Postal Code                                                   1841
# Region                                                     Central
# Product ID                                         FUR-BO-10000468
# ...

# %%
import matplotlib.pyplot as plt

# %%
x.Sales.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(x.index,x.Sales)
plt.xlabel("Days")
plt.ylabel("Sales")
plt.title("Days vs Sales")
# Out:
# Text(0.5, 1.0, 'Days vs Sales')
