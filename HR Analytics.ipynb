# %%
#People Analytics

# %%
import pandas as pd

# %%
#QUESTIONS : https://github.com/sarincr/Business-analytics-Course-with-Python/blob/main/Data%20Analytics/HR%20Analytics.pdf

# %%
df=pd.read_csv("HRDATA.csv")
df
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0         Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3                Alagbe,Trina  10088.0        1.0              1.0  Female
# 4            Anderson, Carol   10069.0        0.0              2.0    Male
# ..                        ...      ...        ...              ...     ...
# 307        Ybarra, Catherine   10301.0        0.0              0.0  Female
# 308          Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309               Zhou, Julia  10043.0        0.0              0.0    Male
# 310             Zima, Colleen  10271.0        0.0              4.0    Male
# 311                       NaN      NaN        NaN              NaN    Male
#
# ...

# %%
df.loc[df["Position"]=="Production Technician I"]
# Out:
#              Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0      Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 3             Alagbe,Trina  10088.0        1.0              1.0  Female
# 4         Anderson, Carol   10069.0        0.0              2.0    Male
# 5        Anderson, Linda    10002.0        0.0              0.0    Male
# 7              Athwal, Sam  10062.0        0.0              4.0    Male
# ..                     ...      ...        ...              ...     ...
# 301          Wilber, Barry  10048.0        1.0              1.0  Female
# 302          Wilkes, Annie  10204.0        0.0              2.0    Male
# 303  Williams, Jacquelyn    10264.0        0.0              0.0    Male
# 307     Ybarra, Catherine   10301.0        0.0              0.0  Female
# 310          Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# ...

# %%
df.loc[df["Position"]=="Production Technician I"].count() #Q1
# Out:
# Employee_Name                 137
# EmpID                         137
# MarriedID                     137
# MaritalStatusID               137
# Gender                        137
# EmpStatusID                   137
# DeptID                        137
# PerfScoreID                   137
# FromDiversityJobFairID        137
# Salary                        137
# Termd                         137
# PositionID                    137
# Position                      137
# State                         137
# Zip                           137
# DOB                           137
# Sex                           137
# MaritalDesc                   137
# CitizenDesc                   137
# DateofHire                    137
# DateofTermination              52
# TermReason                    137
# EmploymentStatus              137
# Department                    137
# ManagerName                   137
# ManagerID                     133
# RecruitmentSource             137
# ...

# %%
df.loc[df["Gender"]=="Male"]
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID Gender  \
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0   Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0   Male
# 4            Anderson, Carol   10069.0        0.0              2.0   Male
# 5           Anderson, Linda    10002.0        0.0              0.0   Male
# 7                 Athwal, Sam  10062.0        0.0              4.0   Male
# ..                        ...      ...        ...              ...    ...
# 306            Woodson, Jason  10135.0        0.0              0.0   Male
# 308          Zamora, Jennifer  10010.0        0.0              0.0   Male
# 309               Zhou, Julia  10043.0        0.0              0.0   Male
# 310             Zima, Colleen  10271.0        0.0              4.0   Male
# 311                       NaN      NaN        NaN              NaN   Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[df["Gender"]=="Male"].count() #Q3
# Out:
# Employee_Name                 193
# EmpID                         193
# MarriedID                     193
# MaritalStatusID               193
# Gender                        194
# EmpStatusID                   193
# DeptID                        193
# PerfScoreID                   193
# FromDiversityJobFairID        193
# Salary                        193
# Termd                         193
# PositionID                    193
# Position                      193
# State                         193
# Zip                           193
# DOB                           193
# Sex                           193
# MaritalDesc                   193
# CitizenDesc                   193
# DateofHire                    193
# DateofTermination              64
# TermReason                    193
# EmploymentStatus              193
# Department                    193
# ManagerName                   193
# ManagerID                     187
# RecruitmentSource             193
# ...

# %%
df.loc[df["ManagerName"]=="Michael Albert"]
# Out:
#               Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0       Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 14            Barton, Nader  10066.0        0.0              2.0    Male
# 23           Blount, Dianna  10294.0        0.0              0.0    Male
# 41         Chace, Beatrice   10067.0        0.0              0.0  Female
# 58        Crimmings,   Jean  10132.0        0.0              0.0    Male
# 83           Erilus, Angela  10299.0        0.0              3.0  Female
# 84        Estremera, Miguel  10280.0        0.0              0.0    Male
# 102         Gentry, Mildred  10159.0        1.0              1.0  Female
# 122     Handschiegl, Joanne  10125.0        1.0              1.0  Female
# 129  Homberger, Adrienne  J  10195.0        1.0              1.0  Female
# 143         Johnson, George  10034.0        1.0              1.0  Female
# 148         Keatts, Kramer   10192.0        0.0              0.0    Male
# ...

# %%
df.loc[df["ManagerName"]=="Michael Albert"].count() #Q3
# Out:
# Employee_Name                 22
# EmpID                         22
# MarriedID                     22
# MaritalStatusID               22
# Gender                        22
# EmpStatusID                   22
# DeptID                        22
# PerfScoreID                   22
# FromDiversityJobFairID        22
# Salary                        22
# Termd                         22
# PositionID                    22
# Position                      22
# State                         22
# Zip                           22
# DOB                           22
# Sex                           22
# MaritalDesc                   22
# CitizenDesc                   22
# DateofHire                    22
# DateofTermination              9
# TermReason                    22
# EmploymentStatus              22
# Department                    22
# ManagerName                   22
# ManagerID                     22
# RecruitmentSource             22
# PerformanceScore              22
# ...

# %%
df.loc[df["EmploymentStatus"]=="Active"] #Q4
# Out:
#            Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0    Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 3           Alagbe,Trina  10088.0        1.0              1.0  Female
# 5      Anderson, Linda    10002.0        0.0              0.0    Male
# 6        Andreola, Colby  10194.0        0.0              0.0  Female
# 7            Athwal, Sam  10062.0        0.0              4.0    Male
# ..                   ...      ...        ...              ...     ...
# 305        Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306       Woodson, Jason  10135.0        0.0              0.0    Male
# 308     Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309          Zhou, Julia  10043.0        0.0              0.0    Male
# 310        Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[(df["EmploymentStatus"]=="Active") & (df["MaritalDesc"]=="Married")] #Q5
# Out:
#          Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 3         Alagbe,Trina  10088.0        1.0              1.0  Female
# 16    Beak, Kimberly    10023.0        1.0              1.0    Male
# 22       Billis, Helen  10003.0        1.0              1.0  Female
# 26   Boutwell, Bonalyn  10081.0        1.0              1.0  Female
# 29          Brown, Mia  10238.0        1.0              1.0  Female
# ..                 ...      ...        ...              ...     ...
# 271   Sullivan, Kissy   10158.0        1.0              1.0    Male
# 272  Sullivan, Timothy  10117.0        1.0              1.0    Male
# 275       Tannen, Biff  10173.0        1.0              1.0  Female
# 287      Turpin, Jumil  10045.0        1.0              1.0    Male
# 288    Valentin,Jackie  10205.0        1.0              1.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[(df["EmploymentStatus"]=="Voluntarily Terminated") & (df["MaritalDesc"]=="Divorced") ]
# Out:
#           Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 4      Anderson, Carol   10069.0        0.0              2.0    Male
# 14        Barton, Nader  10066.0        0.0              2.0    Male
# 103       Gerke, Melisa  10122.0        0.0              2.0  Female
# 119        Gross, Paula  10059.0        0.0              2.0    Male
# 136         Huynh, Ming  10160.0        0.0              2.0    Male
# 158   Langford, Lindsey  10106.0        0.0              2.0    Male
# 224      Power, Morissa  10187.0        0.0              2.0    Male
# 226    Purinton, Janine  10262.0        0.0              2.0    Male
# 229      Rarrick, Quinn  10152.0        0.0              2.0    Male
# 231      Rhoads, Thomas  10058.0        0.0              2.0    Male
# 233       Roberson, May  10230.0        0.0              2.0  Female
# 244       Ruiz, Ricardo  10222.0        0.0              2.0    Male
# 249       Salter, Jason  10229.0        0.0              2.0    Male
# ...

# %%
df.loc[(df["EmploymentStatus"]=="Active") & (df["Salary"]=="<6000")] #Wrong
# Out:
# Empty DataFrame
# Columns: [Employee_Name, EmpID, MarriedID, MaritalStatusID, Gender, EmpStatusID, DeptID, PerfScoreID, FromDiversityJobFairID, Salary, Termd, PositionID, Position, State, Zip, DOB, Sex, MaritalDesc, CitizenDesc, DateofHire, DateofTermination, TermReason, EmploymentStatus, Department, ManagerName, ManagerID, RecruitmentSource, PerformanceScore, EngagementSurvey, EmpSatisfaction, SpecialProjectsCount, LastPerformanceReview_Date, DaysLateLast30, Absences, DistanceFromHome, Age, Attrition, BusinessTravel, Education, EducationField, JobSatisfaction, MonthlyIncome, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, PerformanceRating, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 56 columns]

# %%
for k in df.index: #Q6
    if (df.loc[k,"EmploymentStatus"]=="Active"):
        if (df.loc[k,"Salary"]<60000):
            print(df.loc[k,"Employee_Name"])
# Out:
# Anderson, Linda
# Athwal, Sam
# Bachiochi, Linda
# Bacong, Alejandro
# Barone, Francesco  A
# Beatrice, Courtney
# Becker, Scott
# Bernstein, Sean
# Carey, Michael
# Chan, Lin
# Clukey, Elijian
# Crimmings,   Jean
# Darson, Jene'ya
# Davis, Daniel
# Dee, Randy
# Desimone, Carl
# Dickinson, Geoff
# Dietrich, Jenna
# Dobrin, Denisa  S
# Engdahl, Jean
# England, Rex
# Erilus, Angela
# Fett, Boba
# Fidelia,  Libby
# Garcia, Raul
# Gaul, Barbara
# Gentry, Mildred
# Girifalco, Evelyn
# Gold, Shenice
# Gonzalez, Cayo
# Gordon, David
# Goyal, Roxana
# Handschiegl, Joanne
# Heitzman, Anthony
# Hudson, Jane
# Ivey, Rose
# Jacobi, Hannah
# Keatts, Kramer
# Knapp, Bradley  J
# Langton, Enrico
# Lindsay, Leonara
# Lydon, Allison
# Mahoney, Lauren
# Maurice, Shana
# Carthy, B'rigit
# Medeiros, Jennifer
# Monkfish, Erasumus
# Morway, Tanya
# Myers, Michael
# Newman, Richard
# Ngodup, Shari
# Osturnka, Adeel
# Owad, Clinton
# Pitt, Brad
# Punjabhi, Louis
# Rivera, Haley
# Saar-Beckles, Melinda
# ...

# %%
for k in df.index: #Q7
  if (df.loc[k, "Position" ] == "Production Technician II"):
    if (df.loc[k, "EngagementSurvey" ] == df["EngagementSurvey"].max() ):
      print(df.loc[k,  "Employee_Name"])
# Out:
# Hankard, Earnest
# Hendrickson, Trina
# Manchester, Robyn
# Mancuso, Karen
# Carthy, B'rigit
# Oliver, Brooke
# Winthrop, Jordan

# %%
for k in df.index: #Q8
    if (df.loc[k,"Salary"]==df["Salary"].max()):
        print(df.loc[k,"Position"])
# Out:
# President & CEO

# %%
for k in df.index: #Q9
    if (df.loc[k,'Salary'] < df['Salary'].mean()):
        print(df.loc[k,'Employee_Name'])
# Out:
# Adinolfi, Wilson  K
# Akinkuolie, Sarah
# Alagbe,Trina
# Anderson, Carol
# Anderson, Linda
# Athwal, Sam
# Bachiochi, Linda
# Bacong, Alejandro
# Baczenski, Rachael
# Barbara, Thomas
# Barone, Francesco  A
# Barton, Nader
# Bates, Norman
# Beatrice, Courtney
# Becker, Scott
# Bernstein, Sean
# Biden, Lowan  M
# Billis, Helen
# Blount, Dianna
# Bondwell, Betsy
# Brill, Donna
# Brown, Mia
# Buccheri, Joseph
# Bugali, Josephine
# Burke, Joelle
# Burkett, Benjamin
# Carey, Michael
# Chace, Beatrice
# Chan, Lin
# Chang, Donovan  E
# Chigurh, Anton
# Chivukula, Enola
# Cierpiszewski, Caroline
# Clayton, Rick
# Cloninger, Jennifer
# Close, Phil
# Clukey, Elijian
# Cockel, James
# Cole, Spencer
# Corleone, Michael
# Cornett, Lisa
# Crimmings,   Jean
# Daneault, Lynn
# Darson, Jene'ya
# Davis, Daniel
# Dee, Randy
# DeGweck,  James
# Delarge, Alex
# Demita, Carla
# Desimone, Carl
# Dickinson, Geoff
# Dietrich, Jenna
# DiNocco, Lily
# Dobrin, Denisa  S
# Dunne, Amy
# Eaton, Marianne
# ...

# %%
for k in df.index: #Q10
    if (df.loc[k,'Salary'] < df['Salary'].mean()):
        if (df.loc[k,"EmpSatisfaction"]<3):print(df.loc[k,'Employee_Name'])
# Out:
# Brown, Mia
# Corleone, Michael
# Desimone, Carl
# Dietrich, Jenna
# Erilus, Angela
# Miller, Ned
# O'hare, Lynn
# Sparks, Taylor
# Stansfield, Norman
# Ybarra, Catherine

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["DistanceFromHome"],df["EmpSatisfaction"]) #Q11: Can't draw a valid Conclusion

# %%
plt.scatter(df["DistanceFromHome"],df["EmpSatisfaction"]) #Q11
